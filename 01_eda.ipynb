# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

RAW = '/content/drive/MyDrive/ecommerce-etl-pipeline/Data/raw'

customers    = pd.read_csv(f'{RAW}/olist_customers_dataset.csv')
geolocation  = pd.read_csv(f'{RAW}/olist_geolocation_dataset.csv')
order_items  = pd.read_csv(f'{RAW}/olist_order_items_dataset.csv')
payments     = pd.read_csv(f'{RAW}/olist_order_payments_dataset.csv')
reviews      = pd.read_csv(f'{RAW}/olist_order_reviews_dataset.csv')
orders       = pd.read_csv(f'{RAW}/olist_orders_dataset.csv')
products     = pd.read_csv(f'{RAW}/olist_products_dataset.csv')
sellers      = pd.read_csv(f'{RAW}/olist_sellers_dataset.csv')
category_translation = pd.read_csv(f'{RAW}/product_category_name_translation.csv')

print("All files loaded!")
# Out:
# All files loaded!

# %%
print("=== ORDERS ===")
print("Shape:", orders.shape)
print("Columns:", orders.columns.tolist())
print()
print("=== CUSTOMERS ===")
print("Shape:", customers.shape)
print("Columns:", customers.columns.tolist())
print()
print("=== GEOLOCATION ===")
print("Shape:", geolocation.shape)
print("Columns:", geolocation.columns.tolist())
print()
print("=== ORDER_ITEMS ===")
print("Shape:", order_items.shape)
print("Columns:", order_items.columns.tolist())
print()
print("=== PAYMENTS ===")
print("Shape:", payments.shape)
print("Columns:", payments.columns.tolist())
print()
print("=== REVIEWS ===")
print("Shape:", reviews.shape)
print("Columns:", reviews.columns.tolist())
print()
print("=== PRODUCTS ===")
print("Shape:", products.shape)
print("Columns:", products.columns.tolist())
print()
print("=== SELLERS ===")
print("Shape:", sellers.shape)
print("Columns:", sellers.columns.tolist())
print()
print("=== CATEGORY_TRANSLATION ===")
print("Shape:", category_translation.shape)
print("Columns:",category_translation.columns.tolist())
print()
# Out:
# === ORDERS ===
# Shape: (99441, 8)
# Columns: ['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date']
#
# === CUSTOMERS ===
# Shape: (99441, 5)
# Columns: ['customer_id', 'customer_unique_id', 'customer_zip_code_prefix', 'customer_city', 'customer_state']
#
# === GEOLOCATION ===
# Shape: (1000163, 5)
# Columns: ['geolocation_zip_code_prefix', 'geolocation_lat', 'geolocation_lng', 'geolocation_city', 'geolocation_state']
#
# === ORDER_ITEMS ===
# Shape: (112650, 7)
# Columns: ['order_id', 'order_item_id', 'product_id', 'seller_id', 'shipping_limit_date', 'price', 'freight_value']
#
# === PAYMENTS ===
# Shape: (103886, 5)
# Columns: ['order_id', 'payment_sequential', 'payment_type', 'payment_installments', 'payment_value']
#
# === REVIEWS ===
# Shape: (99224, 7)
# ...

# %%
print("=== MISSING VALUES ===")
print("\nORDERS:")
print(orders.isnull().sum())

print("\nCUSTOMERS:")
print(customers.isnull().sum())

print("\nGEOLOCATION:")
print(geolocation.isnull().sum())

print("\nORDER_ITEMS:")
print(order_items.isnull().sum())

print("\nPAYMENTS:")
print(payments.isnull().sum())

print("\nREVIEWS:")
print(reviews.isnull().sum())

print("\nPRODUCTS:")
print(products.isnull().sum())

print("\nSELLERS:")
print(sellers.isnull().sum())

print("\nCATEGORY_TRANSLATION:")
print(category_translation.isnull().sum())
# Out:
# === MISSING VALUES ===
#
# ORDERS:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64
#
# CUSTOMERS:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64
#
# GEOLOCATION:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64
#
# ORDER_ITEMS:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64
#
# ...

# %%
print("=== DUPLICATE ROWS ===")
print("Orders:", orders.duplicated().sum())
print("customers:", customers.duplicated().sum())
print("geolocation:", geolocation.duplicated().sum())
print("order_items:", order_items.duplicated().sum())
print("payments:", payments.duplicated().sum())
print("reviews:", reviews.duplicated().sum())
print("products:", products.duplicated().sum())
print("sellers:",  sellers.duplicated().sum())
print("category_translation:",  category_translation.duplicated().sum())
# Out:
# === DUPLICATE ROWS ===
# Orders: 0
# customers: 0
# geolocation: 261831
# order_items: 0
# payments: 0
# reviews: 0
# products: 0
# sellers: 0
# category_translation: 0

# %%
print("=== DATA TYPES ===")
print("\nORDERS:")
print(orders.dtypes)
print("\nCUSTOMERS:")
print(customers.dtypes)
print("\nGEOLOCATION:")
print(geolocation.dtypes)
print("\nORDER_ITEMS:")
print(order_items.dtypes)
print("\nPAYMENTS:")
print(payments.dtypes)
print("\nREVIEWS:")
print(reviews.dtypes)
print("\nPRODUCTS:")
print(products.dtypes)
print("\nSELLERS:")
print(sellers.dtypes)
print("\nCATEGORY_TRANSLATION:")
print(category_translation.dtypes)
# Out:
# === DATA TYPES ===
#
# ORDERS:
# order_id                         object
# customer_id                      object
# order_status                     object
# order_purchase_timestamp         object
# order_approved_at                object
# order_delivered_carrier_date     object
# order_delivered_customer_date    object
# order_estimated_delivery_date    object
# dtype: object
#
# CUSTOMERS:
# customer_id                 object
# customer_unique_id          object
# customer_zip_code_prefix     int64
# customer_city               object
# customer_state              object
# dtype: object
#
# GEOLOCATION:
# geolocation_zip_code_prefix      int64
# geolocation_lat                float64
# geolocation_lng                float64
# geolocation_city                object
# geolocation_state               object
# dtype: object
#
# ORDER_ITEMS:
# order_id                object
# order_item_id            int64
# product_id              object
# seller_id               object
# ...

# %%
# Look at the first 5 rows
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
print("=== UNIQUE_VALUES ===")
print(orders['order_status'].unique())
print("=== MINIMUM_DATE ===")
print(orders['order_purchase_timestamp'].min())
print("=== MAXIMUM_DATE ===")
print(orders['order_purchase_timestamp'].max())
print("=== TOTAL_SUM ===")
print(payments['payment_value'].sum())
# Out:
# === UNIQUE_VALUES ===
# ['delivered' 'invoiced' 'shipped' 'processing' 'unavailable' 'canceled'
#  'created' 'approved']
# === MINIMUM_DATE ===
# 2016-09-04 21:15:19
# === MAXIMUM_DATE ===
# 2018-10-17 17:30:18
# === TOTAL_SUM ===
# 16008872.12

# %%
# DATA QUALITY REPORT — Day 2 Findings
#
# 1. Table with most missing values: REVIEWS
# 2. Missing columns in orders: order_approved_at, order_delivered_carrier_date, order_delivered_customer_date
# 3. Date columns stored as: text
# 4. Date range: 2016-09-04 to 2018-10-17
# 5. Total revenue: R$ 16008872.12

# %%
print("=== DUPLICATE ROWS ===")
print("Orders:", orders.duplicated().sum())
print("Customers:", customers.duplicated().sum())
print("Order Items:", order_items.duplicated().sum())
print("Payments:", payments.duplicated().sum())
print("Reviews:", reviews.duplicated().sum())
print("Products:", products.duplicated().sum())
print("Sellers:", sellers.duplicated().sum())
print("Geolocation:", geolocation.duplicated().sum())
# Out:
# === DUPLICATE ROWS ===
# Orders: 0
# Customers: 0
# Order Items: 0
# Payments: 0
# Reviews: 0
# Products: 0
# Sellers: 0
# Geolocation: 261831

# %%
# ================================================
# DATA QUALITY ISSUES TO FIX IN CLEANING (Day 3-5)
# ================================================
#
# 1. DATE COLUMNS — stored as text (object)
#    Fix: convert to datetime using pd.to_datetime()
#    Affects: orders (4 columns), order_items (1 column)
#
# 2. MISSING VALUES — delivery dates in orders
#    Fix: keep nulls for cancelled orders (expected)
#    Drop rows where order_status = delivered BUT
#    delivery date is still missing
#
# 3. MISSING VALUES — review comments
#    Fix: fill with 'No comment' (not critical for analysis)
#
# 4. DUPLICATES — geolocation table
#    Fix: drop_duplicates on zip_code_prefix column
#
# 5. TYPOS — products table column names
#    Fix: rename 'lenght' to 'length'
#
# 6. FILTER — keep only 'delivered' orders for revenue analysis
#    Fix: filter orders where order_status = 'delivered'
# ================================================
